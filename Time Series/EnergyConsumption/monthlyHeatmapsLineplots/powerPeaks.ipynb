# %% [markdown]
# # Power Peaks

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings("ignore")
import powerPeaks_createPlots as cp

# %%
df_2021 = cp.loadData("weatherEnergyData.csv", 2021)

# %% [markdown]
# ## Create Heatmaps for each month of the year
# ### Related to minimum and maximum of the year

# %%
cp.createHeatmap(df=df_2021, normalize=True)

# %% [markdown]
# ### Related to minimum and maximum of each month

# %%
cp.createHeatmap(df=df_2021, normalize=False)

# %% [markdown]
# ## Time Serial Plots

# %%
cp.plotConsumption(df=df_2021, differentiated=False, allPlotsInOne=True)

# %%
cp.plotConsumption(df=df_2021, differentiated=True, allPlotsInOne=False)
